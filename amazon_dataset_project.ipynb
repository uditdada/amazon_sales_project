# %%
import pandas as pd
import matplotlib.pyplot as plt

amazon_data=pd.read_csv("/content/amazon_dataset (4).csv")

# %%
amazon_data
# Out:
#       Unnamed: 0.1   index             Order ID        Date  \
# 0                0       0  405-8078784-5731545  2022-04-30
# 1                1       1  171-9198151-1101146  2022-04-30
# 2                2       2  404-0687676-7273146  2022-04-30
# 3                3       3  403-9615377-8133951  2022-04-30
# 4                4       4  407-1069790-7240320  2022-04-30
# ...            ...     ...                  ...         ...
# 7179          7179  127616  408-2541939-7624343  2022-06-01
# 7180          7180  128095  405-5051629-1702759  2022-06-01
# 7181          7181  128529  402-8671948-6932341  2022-06-01
# 7182          7182  128750  402-8472199-3996364  2022-06-01
# 7183          7183  128794  407-0181564-4652355  2022-06-01
#
#                             Status Fulfilment ship-service-level    Style  \
# 0                        Cancelled   Merchant           Standard   SET389
# 1     Shipped - Delivered to Buyer   Merchant           Standard  JNE3781
# 2                          Shipped     Amazon          Expedited  JNE3371
# 3                        Cancelled   Merchant           Standard    J0341
# 4                          Shipped     Amazon          Expedited  JNE3671
# ...                            ...        ...                ...      ...
# 7179  Shipped - Delivered to Buyer   Merchant           Standard    J0319
# 7180  Shipped - Delivered to Buyer   Merchant           Standard  JNE3398
# 7181  Shipped - Delivered to Buyer   Merchant           Standard  JNE3370
# 7182  Shipped - Delivered to Buyer   Merchant           Standard  JNE3678
# 7183                       Shipped     Amazon          Expedited   SET045
#
#                   SKU       Category  ...        ASIN Courier Status Qty  \
# 0      SET389-KR-NP-S            Set  ...  B09KXVBD7Z        Unknown   0
# 1     JNE3781-KR-XXXL          kurta  ...  B09K3WFS32        Shipped   1
# 2       JNE3371-KR-XL          kurta  ...  B07WV4JV4D        Shipped   1
# 3          J0341-DR-L  Western Dress  ...  B099NRCT7B        Unknown   0
# 4     JNE3671-TU-XXXL            Top  ...  B098714BZP        Shipped   1
# ...               ...            ...  ...         ...            ...  ..
# 7179      J0319-KR-XL          kurta  ...  B08PV3R8YL        Shipped   1
# 7180    JNE3398-KR-XL          kurta  ...  B082W81KNG        Shipped   1
# 7181     JNE3370-KR-S          kurta  ...  B081X6MVKK        Shipped   1
# 7182   JNE3678-TU-XXL            Top  ...  B0943HSR64        Shipped   1
# 7183   SET045-KR-NP-M            Set  ...  B07N81TFNY        Shipped   1
#
#       order_amount_($)       ship-city   ship-state ship-postal-code  \
# 0             7.835425          MUMBAI  MAHARASHTRA         400081.0
# 1             4.912113       BENGALURU    KARNATAKA         560085.0
# 2             3.980505     NAVI MUMBAI  MAHARASHTRA         410210.0
# 3             9.114389      PUDUCHERRY   PUDUCHERRY         605008.0
# 4             6.944711         CHENNAI   TAMIL NADU         600073.0
# ...                ...             ...          ...              ...
# 7179          0.000000      CHANDIGARH   CHANDIGARH         160043.0
# 7180          3.847418       NEW DELHI        DELHI         110002.0
# 7181          3.690134            PUNE  MAHARASHTRA         411038.0
# 7182          6.593846  Dombivali East  MAHARASHTRA         421201.0
# 7183          7.731133       FARIDABAD      HARYANA         121004.0
#
#                                           promotion-ids customer-type Months
# 0                                          No Promotion      customer      4
# 1     Amazon PLCC Free-Financing Universal Merchant ...      customer      4
# 2          IN Core Free Shipping 2015/04/08 23-48-5-108      Business      4
# 3                                          No Promotion      customer      4
# 4                                          No Promotion      customer      4
# ...                                                 ...           ...    ...
# 7179  Amazon PLCC Free-Financing Universal Merchant ...      customer      6
# 7180  Amazon PLCC Free-Financing Universal Merchant ...      customer      6
# 7181  Amazon PLCC Free-Financing Universal Merchant ...      customer      6
# 7182  Amazon PLCC Free-Financing Universal Merchant ...      customer      6
# 7183       IN Core Free Shipping 2015/04/08 23-48-5-108      customer      6
#
# [6929 rows x 21 columns]

# %%
amazon_data.columns
# Out:
# Index(['Unnamed: 0.1', 'index', 'Order ID', 'Date', 'Status', 'Fulfilment',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'order_amount_($)', 'ship-city', 'ship-state',
#        'ship-postal-code', 'promotion-ids', 'customer-type', 'Months', 'size'],
#       dtype='object')

# %%
amazon_data['Date']
# Out:
# 0         04-30-22
# 1         04-30-22
# 2         04-30-22
# 3         04-30-22
# 4         04-30-22
#             ...
# 128970    05-31-22
# 128971    05-31-22
# 128972    05-31-22
# 128973    05-31-22
# 128974    05-31-22
# Name: Date, Length: 128975, dtype: object

# %% [markdown]
# #drop columns

# %%
columns_to_drop=['Unnamed: 0','fulfilled-by','ship-country','currency','Sales Channel ']
amazon_data.drop(columns=columns_to_drop,axis=1,inplace=True)

# %%
out_daterange=amazon_data.loc[(amazon_data.Date<'04-01-2022')|(amazon_data.Date>='06-30-2022')]
out_daterange
# Out:
#        index             Order ID      Date                        Status  \
# 48879  48879  171-7326790-9044369  03-31-22                       Shipped
# 48880  48880  171-7326790-9044369  03-31-22                       Shipped
# 48881  48881  171-7192082-3049169  03-31-22                     Cancelled
# 48882  48882  402-9467302-4929937  03-31-22                       Shipped
# 48883  48883  405-1392423-9557138  03-31-22                       Shipped
# ...      ...                  ...       ...                           ...
# 49045  49045  406-6082415-9289960  03-31-22                       Shipped
# 49046  49046  171-2752302-3297130  03-31-22                       Shipped
# 49047  49047  402-3547933-1598701  03-31-22  Shipped - Delivered to Buyer
# 49048  49048  407-1754629-8915563  03-31-22                     Cancelled
# 49049  49049  407-9937296-0828312  03-31-22                       Shipped
#
#       Fulfilment Sales Channel  ship-service-level    Style  \
# 48879     Amazon      Amazon.in          Expedited  JNE3614
# 48880     Amazon      Amazon.in          Expedited  JNE3294
# 48881   Merchant      Amazon.in           Standard  JNE3461
# 48882     Amazon      Amazon.in          Expedited  JNE3405
# 48883     Amazon      Amazon.in          Expedited  JNE3068
# ...          ...            ...                ...      ...
# 49045     Amazon      Amazon.in          Expedited   SET131
# 49046     Amazon      Amazon.in          Expedited   SET187
# 49047   Merchant      Amazon.in           Standard  JNE3822
# 49048     Amazon      Amazon.in          Expedited   SET325
# 49049     Amazon      Amazon.in          Expedited   SET073
#
#                      SKU Category  ... currency  Amount  \
# 48879       JNE3614-KR-L    kurta  ...      INR  453.00
# 48880       JNE3294-KR-L    kurta  ...      INR  353.00
# 48881       JNE3461-KR-L    kurta  ...      INR  360.95
# 48882    JNE3405-KR-XXXL    kurta  ...      INR  449.00
# 48883     JNE3068-KR-A-L    kurta  ...      INR  688.00
# ...                  ...      ...  ...      ...     ...
# 49045  SET131-KR-NP-A-XL      Set  ...      INR  567.00
# 49046     SET187-KR-DH-M      Set  ...      INR  599.00
# 49047       JNE3822-KR-L    kurta  ...      INR  490.00
# 49048     SET325-KR-NP-S      Set  ...      NaN     NaN
# 49049    SET073-KR-SHA-M      Set  ...      INR  791.00
#
#                            ship-city      ship-state ship-postal-code  \
# 48879  ARANI TIRUVANNAMALAI DISTRICT      TAMIL NADU         632317.0
# 48880  ARANI TIRUVANNAMALAI DISTRICT      TAMIL NADU         632317.0
# 48881  ARANI TIRUVANNAMALAI DISTRICT      TAMIL NADU         632317.0
# 48882                      PANCHKULA         HARYANA         134116.0
# 48883                       Tirupati  ANDHRA PRADESH         517501.0
# ...                              ...             ...              ...
# 49045                      NEW DELHI           DELHI         110025.0
# 49046                         RANCHI       JHARKHAND         834004.0
# 49047                        UDAIPUR       RAJASTHAN         313001.0
# 49048                           REWA  MADHYA PRADESH         486001.0
# 49049                           Gaya           BIHAR         823001.0
#
#        ship-country                                      promotion-ids    B2B  \
# 48879            IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 48880            IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 48881            IN                                                NaN  False
# 48882            IN                                                NaN  False
# 48883            IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# ...             ...                                                ...    ...
# 49045            IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 49046            IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 49047            IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 49048            IN                                                NaN  False
# 49049            IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
#        fulfilled-by Unnamed: 22
# 48879           NaN         NaN
# 48880           NaN         NaN
# 48881     Easy Ship         NaN
# 48882           NaN         NaN
# 48883           NaN         NaN
# ...             ...         ...
# 49045           NaN         NaN
# 49046           NaN         NaN
# 49047     Easy Ship         NaN
# 49048           NaN         NaN
# 49049           NaN         NaN
#
# [171 rows x 24 columns]

# %% [markdown]
# # drop duplicates

# %%
duplited_col=amazon_data.apply(lambda col:col.duplicated().any())
duplited_col
# Out:
# index                 False
# Order ID               True
# Date                   True
# Status                 True
# Fulfilment             True
# Sales Channel          True
# ship-service-level     True
# Style                  True
# SKU                    True
# Category               True
# Size                   True
# ASIN                   True
# Courier Status         True
# Qty                    True
# currency               True
# Amount                 True
# ship-city              True
# ship-state             True
# ship-postal-code       True
# ship-country           True
# promotion-ids          True
# B2B                    True
# fulfilled-by           True
# dtype: bool

# %%
amazon_data=amazon_data.drop_duplicates(subset=['ASIN'])

# %%
amazon_data=amazon_data.drop_duplicates(subset=['Order ID'])

amazon_data['Qty']=amazon_data['Qty'].fillna(0)

# %%
amazon_data['Amount']=amazon_data['Amount'].fillna(0)

# %%
amazon_data['ship-postal-code']=amazon_data['ship-postal-code'].fillna(0)

# %%
amazon_data['Courier Status']=amazon_data['Courier Status'].fillna('Unknown')

# %%
amazon_data['promotion-ids']=amazon_data['promotion-ids'].fillna('No Promotion')

# %%
amazon_data['Courier Status'].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
amazon_data['promotion-ids'].unique()

# %%
amazon_data['ship-city'].unique()
# Out:
# array(['MUMBAI', 'BENGALURU', 'NAVI MUMBAI', ..., 'PARLI VAIJNATH',
#        'WALUJ MIDC', 'Dombivali East'], dtype=object)

# %%
amazon_data.loc[amazon_data['ship-city']=="Nan"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, index, Order ID, Date, Status, Fulfilment, Sales Channel , ship-service-level, Style, SKU, Category, Size, ASIN, Courier Status, Qty, currency, order_amount_($), ship-city, ship-state, ship-postal-code, ship-country, promotion-ids, customer-type, fulfilled-by, Months]
# Index: []
#
# [0 rows x 26 columns]

# %%
amazon_data['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'Gujarat', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'HIMACHAL PRADESH', 'ARUNACHAL PRADESH',
#        'MANIPUR', 'Goa', 'MEGHALAYA', 'GOA', 'PUNJAB', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'Delhi', 'Rajshthan',
#        'ANDAMAN & NICOBAR ', 'punjab', 'MIZORAM', 'New Delhi',
#        'rajasthan', 'Rajasthan', 'Punjab', 'delhi', 'Chandigarh',
#        'Sikkim'], dtype=object)

# %%
amazon_data['ship-postal-code'].unique()
# Out:
# array([400081., 560085., 410210., ..., 452020., 754001., 431136.])

# %% [markdown]
# #renaming columns

# %%
amazon_data=amazon_data.rename(columns={'B2B':'customer-type'})

# %%
amazon_data=amazon_data.rename(columns={'Amount':'order_amount_($)'})

# %%
amazon_data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'customer-type', 'fulfilled-by'],
#       dtype='object')

# %% [markdown]
# #renaming customer type values

# %%
amazon_data.loc[amazon_data['customer-type']==True,'customer-type']='Business'
# Out:
# <ipython-input-5-519e87e20aaf>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Business' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   amazon_data.loc[amazon_data['customer-type']==True,'customer-type']='Business'

# %%
amazon_data.loc[amazon_data['customer-type']==False,'customer-type']='customer'

# %% [markdown]
# #conversion INR to USD

# %%
exchange=0.0120988
amazon_data['order_amount_($)']=amazon_data['order_amount_($)'].apply(lambda x:x*exchange)

# %% [markdown]
# #adding month column and droping some dates

# %%
amazon_data['Date']=pd.to_datetime(amazon_data['Date'])
# Out:
# <ipython-input-36-adf5a8deec00>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   amazon_data['Date']=pd.to_datetime(amazon_data['Date'])

# %%
amazon_data['Months']=amazon_data['Date'].dt.month

# %%
amazon_data.drop(amazon_data[amazon_data['Date'].dt.month==3].index,inplace=True)

# %% [markdown]
# #saving file

# %%
amazon_data.to_csv("amazon_dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
size_order = ['S', 'M', 'L',
'Xl','XS','XXL','3XL','4XL','5XL','6XL','Free']
amazon_data['size'] = pd.Categorical(amazon_data['Size'], categories=size_order,
ordered=True)
amazon_data
# Out:
# <ipython-input-17-1b4001139c1e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_data['size'] = pd.Categorical(amazon_data['Size'], categories=size_order,
#       Unnamed: 0.1   index             Order ID        Date  \
# 0                0       0  405-8078784-5731545  2022-04-30
# 1                1       1  171-9198151-1101146  2022-04-30
# 2                2       2  404-0687676-7273146  2022-04-30
# 3                3       3  403-9615377-8133951  2022-04-30
# 4                4       4  407-1069790-7240320  2022-04-30
# ...            ...     ...                  ...         ...
# 7179          7179  127616  408-2541939-7624343  2022-06-01
# 7180          7180  128095  405-5051629-1702759  2022-06-01
# 7181          7181  128529  402-8671948-6932341  2022-06-01
# 7182          7182  128750  402-8472199-3996364  2022-06-01
# 7183          7183  128794  407-0181564-4652355  2022-06-01
#
#                             Status Fulfilment ship-service-level    Style  \
# 0                        Cancelled   Merchant           Standard   SET389
# 1     Shipped - Delivered to Buyer   Merchant           Standard  JNE3781
# 2                          Shipped     Amazon          Expedited  JNE3371
# 3                        Cancelled   Merchant           Standard    J0341
# 4                          Shipped     Amazon          Expedited  JNE3671
# ...                            ...        ...                ...      ...
# 7179  Shipped - Delivered to Buyer   Merchant           Standard    J0319
# 7180  Shipped - Delivered to Buyer   Merchant           Standard  JNE3398
# 7181  Shipped - Delivered to Buyer   Merchant           Standard  JNE3370
# 7182  Shipped - Delivered to Buyer   Merchant           Standard  JNE3678
# 7183                       Shipped     Amazon          Expedited   SET045
#
#                   SKU       Category  ... Courier Status Qty order_amount_($)  \
# 0      SET389-KR-NP-S            Set  ...        Unknown   0         7.835425
# 1     JNE3781-KR-XXXL          kurta  ...        Shipped   1         4.912113
# 2       JNE3371-KR-XL          kurta  ...        Shipped   1         3.980505
# 3          J0341-DR-L  Western Dress  ...        Unknown   0         9.114389
# 4     JNE3671-TU-XXXL            Top  ...        Shipped   1         6.944711
# ...               ...            ...  ...            ...  ..              ...
# 7179      J0319-KR-XL          kurta  ...        Shipped   1         0.000000
# 7180    JNE3398-KR-XL          kurta  ...        Shipped   1         3.847418
# 7181     JNE3370-KR-S          kurta  ...        Shipped   1         3.690134
# 7182   JNE3678-TU-XXL            Top  ...        Shipped   1         6.593846
# 7183   SET045-KR-NP-M            Set  ...        Shipped   1         7.731133
#
#            ship-city   ship-state ship-postal-code  \
# 0             MUMBAI  MAHARASHTRA         400081.0
# 1          BENGALURU    KARNATAKA         560085.0
# 2        NAVI MUMBAI  MAHARASHTRA         410210.0
# 3         PUDUCHERRY   PUDUCHERRY         605008.0
# 4            CHENNAI   TAMIL NADU         600073.0
# ...              ...          ...              ...
# 7179      CHANDIGARH   CHANDIGARH         160043.0
# 7180       NEW DELHI        DELHI         110002.0
# 7181            PUNE  MAHARASHTRA         411038.0
# 7182  Dombivali East  MAHARASHTRA         421201.0
# 7183       FARIDABAD      HARYANA         121004.0
#
#                                           promotion-ids  customer-type Months  \
# 0                                          No Promotion       customer      4
# 1     Amazon PLCC Free-Financing Universal Merchant ...       customer      4
# 2          IN Core Free Shipping 2015/04/08 23-48-5-108       Business      4
# 3                                          No Promotion       customer      4
# 4                                          No Promotion       customer      4
# ...                                                 ...            ...    ...
# 7179  Amazon PLCC Free-Financing Universal Merchant ...       customer      6
# 7180  Amazon PLCC Free-Financing Universal Merchant ...       customer      6
# 7181  Amazon PLCC Free-Financing Universal Merchant ...       customer      6
# 7182  Amazon PLCC Free-Financing Universal Merchant ...       customer      6
# 7183       IN Core Free Shipping 2015/04/08 23-48-5-108       customer      6
#
#      size
# 0       S
# 1     3XL
# 2     NaN
# 3       L
# 4     3XL
# ...   ...
# 7179  NaN
# 7180  NaN
# 7181    S
# 7182  XXL
# 7183    M
#
# [6929 rows x 22 columns]

# %% [markdown]
# #analysis

# %%
#top 3 category_revenue products
category_revenue=amazon_data.groupby('Category')['order_amount_($)'].sum()
top_3=category_revenue.sort_values(ascending=False).head(3)
print(top_3)
# Out:
# Category
# Set      23363.865401
# kurta    14430.321395
# Top       4409.685327
# Name: order_amount_($), dtype: float64

# %%
#percentage_top3 products
total_revenue=category_revenue.sum()
top_3_per=(top_3/total_revenue)*100
print(top_3_per)
# Out:
# Category
# Set      47.829310
# kurta    29.541016
# Top       9.027282
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue of top 3 products
plt.figure(figsize=(5,3))
top_3.plot(kind='bar',color='blue')
plt.title('top 3 category')
plt.xlabel('product category')
plt.ylabel('revenue')
plt.show()

# %%
bottom_3=category_revenue.sort_values().head(3)
print(bottom_3)
# Out:
# Category
# Dupatta      7.380268
# Saree      617.323969
# Blouse     707.310851
# Name: order_amount_($), dtype: float64

# %%
monthwise_revenue=amazon_data.groupby('Months')['order_amount_($)'].sum()
top_months=monthwise_revenue.sort_values(ascending=False).head(3)
top_months.index = pd.to_datetime(top_months.index, format='%m').strftime('%B')
print(top_months)
# Out:
# Months
# April    38486.943878
# May       6823.806077
# June      3537.676900
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue of top 3 months
plt.figure(figsize=(5,3))
top_months.plot(kind='bar',color='green')
plt.title('top 3 months')
plt.xlabel('months')
plt.ylabel('revenue')
plt.show()

# %%
#top 3 category_revenue products acc to average price
average_category_revenue=amazon_data.groupby('Category')['order_amount_($)'].mean()
top_5_average=average_category_revenue.sort_values(ascending=False).head(5)
print(top_5_average)
# Out:
# Category
# Set              9.674478
# Saree            9.213791
# Western Dress    8.505658
# Ethnic Dress     7.775856
# Top              5.726864
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue_average of top 5 products
plt.figure(figsize=(5,3))
top_5_average.plot(kind='pie')
plt.title('top 5 products')
plt.show()

# %%
#average_revenue acc to customer type
average_ctype_revenue=amazon_data.groupby('customer-type')['order_amount_($)'].mean()
customer_type_average=average_ctype_revenue.sort_values(ascending=False)
print(customer_type_average)
# Out:
# customer-type
# Business    7.102907
# customer    7.049373
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue_average of top 5 products
plt.figure(figsize=(5,3))
customer_type_average.plot(kind='pie')
plt.title('customer type average')
plt.show()

# %%
#top 5 state_revenue acc to average price
total_state_revenue=amazon_data.groupby('ship-state')['order_amount_($)'].sum()
top_5_state=total_state_revenue.sort_values(ascending=False).head(5)
print(top_5_state)
# Out:
# ship-state
# MAHARASHTRA      8320.383839
# KARNATAKA        6193.388182
# TELANGANA        4140.931416
# UTTAR PRADESH    4084.165904
# TAMIL NADU       4069.489696
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue of top 5 state
plt.figure(figsize=(5,3))
top_5_state.plot(kind='bar',color='orange')
plt.title('top 5 state')
plt.xlabel('state')
plt.ylabel('revenue')
plt.show()

# %%
#top 5 state_revenue acc to western dress
total_state_wes=amazon_data.query("Category=='Western Dress'").groupby('ship-state')['order_amount_($)'].sum()
top_5_state_wes=total_state_wes.sort_values(ascending=False).head(5)
print(top_5_state_wes)
# Out:
# ship-state
# MAHARASHTRA      620.215582
# KARNATAKA        533.847451
# TELANGANA        475.147582
# TAMIL NADU       303.923066
# UTTAR PRADESH    238.751549
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue of top 5 state
plt.figure(figsize=(5,3))
top_5_state.plot(kind='bar',color='red')
plt.title('top 5 state')
plt.xlabel('state')
plt.ylabel('revenue')
plt.show()

# %%
#top 5 state acc to bottom 3
total_state_bottom3=amazon_data.query("Category in ['Dupatta','Saree','Blouse']").groupby('ship-state')['order_amount_($)'].sum()
top_5_state_bottom=total_state_bottom3.sort_values(ascending=False).head(5)
print(top_5_state_bottom)
# Out:
# ship-state
# UTTAR PRADESH    170.987138
# KARNATAKA        165.890639
# MAHARASHTRA      162.853962
# TELANGANA        145.953632
# TAMIL NADU       130.267780
# Name: order_amount_($), dtype: float64

# %%
#plotting_revenue of top 5 state
plt.figure(figsize=(5,3))
top_5_state_bottom.plot(kind='bar',color='yellow')
plt.title('top 5 state')
plt.xlabel('state')
plt.ylabel('revenue')
plt.show()
